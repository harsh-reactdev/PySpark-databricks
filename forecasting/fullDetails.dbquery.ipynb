-- %%
CREATE TABLE toner_usage (
    deviceId STRING,
    dealerId STRING,
    L1DealerId STRING,
    L2DealerId STRING,
    L3DealerId STRING,
    divisionId STRING,
    servicingDealerId STRING,
    customerId STRING,

    modelName STRING,
    serialNumber STRING,

    timestamp STRING,
    lastSuppliesUpdate STRING,

    relatedGroupId STRING,
    type STRING,
    description STRING,
    state STRING,

    color STRING,
    typical STRING,
    unit STRING,
    capacity STRING,

    printCount INT,
    tonerNumber INT,

    tagIds STRING,
    forecastingList STRING
)
USING DELTA;
