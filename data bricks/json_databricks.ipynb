# %%
json_data = spark.read.json('/Workspace/Users/harsh.reactdev@gmail.com/PySpark-databricks/data bricks/02-28.json')

display(json_data)

# %%
json_data.printSchema()

# %%
from pyspark.sql.functions import col, to_timestamp

flat_df = json_data.select(
    col("Body.mnsn").alias("mnsn"),
    col("Body.scheduleName").alias("schedule_name"),
    col("Body.smsProperties.device.serialId").alias("device_serial_id"),
    col("Body.smsProperties.device.modelName").alias("device_model"),
    col("Body.smsProperties.device.statusRawValue").alias("device_status"),
    col("Body.timestamp").alias("event_timestamp"),
    col("Body.type").alias("event_type"),
    col("Properties.customerId").alias("customer_id"),
    col("Properties.dealerId").alias("dealer_id")
)

display(flat_df)
flat_df.printSchema()

flat_df = flat_df.withColumn(
    "event_time",
    to_timestamp(col("event_timestamp") / 1000)
)
display(flat_df)

delta_path = "/Workspace/Users/harsh.reactdev@gmail.com/PySpark-databricks/data bricks/02-28.json"
flat_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save(delta_path)

# %%
from pyspark.sql.functions import to_timestamp, col

df_transformed = (
    json_data
    .withColumn("event_time", to_timestamp(col("Body.timestamp")))
    .withColumnRenamed("deviceId", "device_id")
)

display(df_transformed)

# %%
# %sql
SHOW EXTERNAL LOCATIONS;
# Out:
# Databricks data profile. Run in Databricks to view.
